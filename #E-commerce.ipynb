# %% [markdown]
# # menna allah mohamed/Data science Training/project1

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(font_scale=1.3)


from sklearn.preprocessing import LabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import scipy
from sklearn.linear_model import Ridge

# %%
df = pd.read_csv("data.csv", encoding="ISO-8859-1", dtype={'CustomerID': str}, parse_dates=['InvoiceDate'])
df.shape
# Out:
# (541909, 8)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %%
missing_percentage =df.isnull().mean()* 100
missing_percentage
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %%
#remove the none customer IDs
df = df.loc[(df.CustomerID.isnull()==False)].copy()

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 0      2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2      2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3      2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4      2010-12-01 08:26:00       3.39      17850  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2011-12-09 12:50:00       0.85      12680          France
# 541905 2011-12-09 12:50:00       2.10      12680          France
# 541906 2011-12-09 12:50:00       4.15      12680          France
# 541907 2011-12-09 12:50:00       4.15      12680          France
# 541908 2011-12-09 12:50:00       4.95      12680          France
#
# [406829 rows x 8 columns]

# %%
# Just for Checking 
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
country_counts = df.Country.value_counts().sort_values(ascending=False).iloc[0:20]
country_counts
# Out:
# United Kingdom     361878
# Germany              9495
# France               8491
# EIRE                 7485
# Spain                2533
# Netherlands          2371
# Belgium              2069
# Switzerland          1877
# Portugal             1480
# Australia            1259
# Norway               1086
# Italy                 803
# Channel Islands       758
# Finland               695
# Cyprus                622
# Sweden                462
# Austria               401
# Denmark               389
# Japan                 358
# Poland                341
# Name: Country, dtype: int64

# %% [markdown]
# # Q1: Which Country makes the most transactions?

# %%
country_counts = df.Country.value_counts().sort_values(ascending=False).iloc[0:20]
plt.figure(figsize=(20,5))
sns.barplot(country_counts.index, country_counts.values, palette="Greens_r")
plt.ylabel("Counts")
plt.title("Which countries made the most transactions?");
plt.xticks(rotation=90);
plt.yscale("log")

# %% [markdown]
# # Q6: Calculate the Total Revenue for each Row

# %%
df['revenue']=df.Quantity*df.UnitPrice
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country  revenue
# 0      2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1      2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 2      2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00
# 3      2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 4      2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# ...                    ...        ...        ...             ...      ...
# 541904 2011-12-09 12:50:00       0.85      12680          France    10.20
# 541905 2011-12-09 12:50:00       2.10      12680          France    12.60
# 541906 2011-12-09 12:50:00       4.15      12680          France    16.60
# 541907 2011-12-09 12:50:00       4.15      12680          France    16.60
# 541908 2011-12-09 12:50:00       4.95      12680          France    14.85
#
# [406829 rows x 9 columns]

# %% [markdown]
# # Q2: Show the Top 10 Customers how made the largest Revenue

# %%
df_top_10 = {'CustomerID':df.groupby('CustomerID').revenue.sum().sort_values(ascending=False)[:10].index,
            'revenue':df.groupby('CustomerID').revenue.sum().sort_values(ascending=False)[:10].values}
df_top_10 = pd.DataFrame(df_top_10)
df_top_10
# Out:
#   CustomerID    revenue
# 0      14646  279489.02
# 1      18102  256438.49
# 2      17450  187482.17
# 3      14911  132572.62
# 4      12415  123725.45
# 5      14156  113384.14
# 6      17511   88125.38
# 7      16684   65892.08
# 8      13694   62653.10
# 9      15311   59419.34

# %% [markdown]
# # Q3: Show Top 5 frequent Customers

# %%
df['frequency'] = df['CustomerID'].map(df['CustomerID'].value_counts())
w=df.drop_duplicates(subset="CustomerID")
w
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 26        536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 46        536371     22086      PAPER CHAIN KIT 50'S CHRISTMAS         80
# 65        536374     21258           VICTORIAN SEWING BOX LARGE        32
# ...          ...       ...                                  ...       ...
# 536969    581233     22178      VICTORIAN GLASS HANGING T-LIGHT         6
# 537255    581241     22922     FRIDGE MAGNETS US DINER ASSORTED        12
# 538064    581385    84029G  KNITTED UNION FLAG HOT WATER BOTTLE        24
# 538812    581416     22466       FAIRY TALE COTTAGE NIGHT LIGHT         1
# 541768    581578      POST                              POSTAGE         3
#
#                InvoiceDate  UnitPrice CustomerID         Country  revenue  \
# 0      2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 9      2010-12-01 08:34:00       1.69      13047  United Kingdom    54.08
# 26     2010-12-01 08:45:00       3.75      12583          France    90.00
# 46     2010-12-01 09:00:00       2.55      13748  United Kingdom   204.00
# 65     2010-12-01 09:09:00      10.95      15100  United Kingdom   350.40
# ...                    ...        ...        ...             ...      ...
# 536969 2011-12-08 10:33:00       1.95      13436  United Kingdom    11.70
# 537255 2011-12-08 10:58:00       0.85      15520  United Kingdom    10.20
# 538064 2011-12-08 13:11:00       3.75      13298  United Kingdom    90.00
# 538812 2011-12-08 14:58:00       1.95      14569  United Kingdom     1.95
# 541768 2011-12-09 12:16:00      18.00      12713         Germany    54.00
#
#         frequency
# 0             312
# 9             196
# 26            251
# 46             28
# 65              6
# ...           ...
# 536969         12
# 537255         18
# 538064          2
# 538812         12
# 541768         38
#
# [4372 rows x 10 columns]

# %%
df['frequency'] =df['CustomerID'].map(df['CustomerID'].value_counts())
df_top_cust = {'CustomerID':w.groupby('CustomerID').frequency.sum().sort_values(ascending=False)[:5].index,
            'frequency':w.groupby('CustomerID').frequency.sum().sort_values(ascending=False)[:5].values}
df_top_cust = pd.DataFrame(df_top_cust)
df_top_cust
# Out:
#   CustomerID  frequency
# 0      17841       7983
# 1      14911       5903
# 2      14096       5128
# 3      12748       4642
# 4      14606       2782

# %%
f"{df.shape[0]:,}"
# Out:
# '406,829'

# %% [markdown]
# # Q4: Create a histogram that reveals the count of words of 𝑫𝒆𝒔𝒄𝒓𝒊𝒑𝒕𝒊𝒐𝒏

# %%
df["DescriptionLength"] = df.Description.apply(lambda l: len(l))

# %%
fig, ax = plt.subplots(1, figsize=(20,5))
sns.countplot(df.DescriptionLength,color='purple')

# %% [markdown]
# # Q5: Extract {𝑌𝑒𝑎𝑟, 𝑀𝑜𝑛𝑡ℎ, 𝑊𝑒𝑒𝑘, 𝑊𝑒𝑒𝑘𝐷𝑎𝑦, 𝐷𝑎𝑦, 𝐷𝑎𝑦𝑂𝑓𝑌𝑒𝑎𝑟,𝐷𝑎𝑡𝑒} features from 𝐼𝑛𝑣𝑜𝑖𝑐𝑒𝐷𝑎𝑡𝑒 feature

# %%
df["Year"] = df.InvoiceDate.dt.year
df["Quarter"] = df.InvoiceDate.dt.quarter
df["Month"] = df.InvoiceDate.dt.month
df["Week"] = df.InvoiceDate.dt.week
df["Weekday"] = df.InvoiceDate.dt.weekday
df["Day"] = df.InvoiceDate.dt.day
df["Dayofyear"] = df.InvoiceDate.dt.dayofyear
df["Date"] = pd.to_datetime(df[['Year', 'Month', 'Day']])

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  revenue  \
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom    20.34
#
#    frequency  DescriptionLength  Year  Quarter  Month  Week  Weekday  Day  \
# 0        312                 34  2010        4     12    48        2    1
# 1        312                 19  2010        4     12    48        2    1
# 2        312                 30  2010        4     12    48        2    1
# 3        312                 35  2010        4     12    48        2    1
# 4        312                 30  2010        4     12    48        2    1
#
#    Dayofyear       Date
# 0        335 2010-12-01
# 1        335 2010-12-01
# 2        335 2010-12-01
# 3        335 2010-12-01
# 4        335 2010-12-01

# %% [markdown]
# # Q7 & Q8: Aggregate Revenue & Quantity across the grouped_features

# %%
grouped_features = ["Date", "Year", "Quarter","Month", "Week", "Weekday", "Dayofyear", "Day","StockCode"]

# %%
daily_data = pd.DataFrame(df.groupby(grouped_features).Quantity.sum(), columns=["Quantity"])
daily_data["revenue"] = df.groupby(grouped_features).revenue.sum()
daily_data = daily_data.reset_index()
daily_data.head(5)
# Out:
#         Date  Year  Quarter  Month  Week  Weekday  Dayofyear  Day StockCode  \
# 0 2010-12-01  2010        4     12    48        2        335    1     10002
# 1 2010-12-01  2010        4     12    48        2        335    1     10125
# 2 2010-12-01  2010        4     12    48        2        335    1     10133
# 3 2010-12-01  2010        4     12    48        2        335    1    15044B
# 4 2010-12-01  2010        4     12    48        2        335    1   15056BL
#
#    Quantity  revenue
# 0        60    51.00
# 1         2     1.70
# 2         5     4.25
# 3         1     2.95
# 4        20   113.00
